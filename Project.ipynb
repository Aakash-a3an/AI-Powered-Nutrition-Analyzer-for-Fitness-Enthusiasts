# %% [markdown]
# #UNZIP

# %%
#Unzip the Dataset
#!unzip '/content/Dataset-20221108T151518Z-001.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8796.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8956.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8892.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_904.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_9047.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_9442.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8617.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_9123.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8904.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8978.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_9083.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8679.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8645.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8902.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_8007.jpg
#   inflating: Dataset/TRAIN_SET/APPLES/n07740461_9005.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #IMPORT LIBRARIES

# %%
#Importing Required Libraries
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #IMAGE AUGUMENTATION

# %%
train_datagen=ImageDataGenerator(rescale=1./255,
                                 zoom_range=0.2,
                                 horizontal_flip=True,
                                 vertical_flip=False)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory(r"/content/drive/MyDrive/Dataset/TRAIN_SET",
                                          target_size=(64,64),
                                          class_mode='categorical',
                                          batch_size=24)
# Out:
# Found 4118 images belonging to 5 classes.

# %%
x_test=test_datagen.flow_from_directory(r"/content/drive/MyDrive/Dataset/TEST_SET",
                                        target_size=(64,64),
                                        class_mode='categorical',
                                        batch_size=24)
# Out:
# Found 929 images belonging to 3 classes.

# %%
x_train.class_indices
# Out:
# {'APPLES': 0, 'BANANA': 1, 'ORANGE': 2, 'PINEAPPLE': 3, 'WATERMELON': 4}

# %% [markdown]
# #CNN MODEL CREATION AND ADDING LAYERS

# %%
model=Sequential()

# %% [markdown]
# #INPUT LAYERS (CONVOLUTION, MAXPOOLING, FLATTEN)

# %%
model.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  flatten (Flatten)           (None, 30752)             0
#
# ...
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #HIDDEN LAYERS

# %%
model.add(Dense(300,activation='relu'))
model.add(Dense(150,activation='relu'))

# %% [markdown]
# #OUTPUT LAYERS

# %%
model.add(Dense(5,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
len(x_train)
# Out:
# 172

# %% [markdown]
# #TRAIN THE MODEL

# %%
model.fit_generator(x_train,steps_per_epoch=len(x_train),
                    validation_data=x_test,
                    validation_steps=len(x_test), epochs= 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/10
# 172/172 [==============================] - ETA: 0s - loss: 0.6491 - accuracy: 0.7438
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-19-44f7d828eed1> in <module>
#       1 model.fit_generator(x_train,steps_per_epoch=len(x_train),
#       2                     validation_data=x_test,
# ----> 3                     validation_steps=len(x_test), epochs= 10)
#
# ...

# %% [markdown]
# #SAVE THE MODEL

# %%
model.save('Project.h5')

# %% [markdown]
# #TEST THE MODEL

# %%
ls
# Out:
# Dataset/  Dataset-20221108T151518Z-001.zip  Project.h5  sample_data/

# %%
# Testing 1
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/istockphoto-1357864202-170667a(1).jpeg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 131ms/step
# 'ORANGE'

# %%
# Testing 2
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/istockphoto-1357864202-170667a.jpeg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 'ORANGE'

# %%
# Testing 3
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/APPLES/n07740461_10011.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 'ORANGE'

# %%
#Testing 4
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/APPLES/n07740461_10080.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 'APPLES'

# %%
#Testing 5
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/ORANGE/n07749192_10081.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 'ORANGE'

# %%
#Testing 6
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/BANANA/0WSGFT9BFDSM.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 'ORANGE'

# %%
#Testing 7
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/BANANA/081Y3HXC2A4Y.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 'APPLES'

# %%
#Testing 8
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/BANANA/0SF1HXERAMSH.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 'ORANGE'

# %%
#Testing 9
from tensorflow.keras.preprocessing import image
img = image.load_img('/content/Dataset/TEST_SET/BANANA/14VGCGRDFBRV.jpg',target_size=(64,64)) # Reading image
x = image.img_to_array(img) # Converting image into array
x = np.expand_dims(x,axis=0) # expanding Dimensions
pred = np.argmax(model.predict(x)) # Predicting the higher probablity index
op = ['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON'] # Creating list
op[pred] # List indexing with output
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 'BANANA'
